# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/New_model_Classification/survey (1).csv")

# %%
df =pd.DataFrame(df)

# %%
df.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
df.shape
# Out:
# (1259, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   object
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   object
#  3   Country                    1259 non-null   object
#  4   state                      744 non-null    object
#  5   self_employed              1241 non-null   object
#  6   family_history             1259 non-null   object
#  7   treatment                  1259 non-null   object
#  8   work_interfere             995 non-null    object
#  9   no_employees               1259 non-null   object
#  10  remote_work                1259 non-null   object
#  11  tech_company               1259 non-null   object
#  12  benefits                   1259 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                         515
# self_employed                  18
# family_history                  0
# treatment                       0
# work_interfere                264
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1095
# dtype: int64

# %%
df.describe(include=['object', 'float64', 'int64'])
# Out:
#                   Timestamp           Age Gender        Country state  \
# count                  1259  1.259000e+03   1259           1259   744
# unique                 1246           NaN     49             48    45
# top     2014-08-27 12:44:51           NaN   Male  United States    CA
# freq                      2           NaN    615            751   138
# mean                    NaN  7.942815e+07    NaN            NaN   NaN
# std                     NaN  2.818299e+09    NaN            NaN   NaN
# min                     NaN -1.726000e+03    NaN            NaN   NaN
# 25%                     NaN  2.700000e+01    NaN            NaN   NaN
# 50%                     NaN  3.100000e+01    NaN            NaN   NaN
# 75%                     NaN  3.600000e+01    NaN            NaN   NaN
# max                     NaN  1.000000e+11    NaN            NaN   NaN
#
#        self_employed family_history treatment work_interfere no_employees  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['treatment'].value_counts()
# Out:
# Yes    637
# No     622
# Name: treatment, dtype: int64

# %%
df['treatment'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
#Data is Balanced...

# %%
df['comments'].sample(5)
# Out:
# 251    NaN
# 207    NaN
# 960    NaN
# 865    NaN
# 563    NaN
# Name: comments, dtype: object

# %%
1259-1095
# Out:
# 164

# %%
#most of the row in comment column is null because most of the people did not fill the comment as it is optional so we drop this column

# %%
df.drop(columns='comments',inplace=True)

# %%
df.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...   anonymity  \
# 0             No       Yes          Often            6-25  ...         Yes
# 1             No        No         Rarely  More than 1000  ...  Don't know
# 2             No        No         Rarely            6-25  ...  Don't know
# 3            Yes       Yes          Often          26-100  ...          No
# 4             No        No          Never         100-500  ...  Don't know
#
#                 leave mental_health_consequence phys_health_consequence  \
# ...

# %%
#we are dropping the  Timestamp column as it is irrelevant
df.drop(columns='Timestamp',inplace=True)

# %%
for column in df.columns:
  if df[column].dtype =='object':
    num_unique_values = df[column].nunique()
    print(f"Column '{column}' has {num_unique_values} unique categories.")
# Out:
# Column 'Gender' has 49 unique categories.
# Column 'Country' has 48 unique categories.
# Column 'state' has 45 unique categories.
# Column 'self_employed' has 2 unique categories.
# Column 'family_history' has 2 unique categories.
# Column 'treatment' has 2 unique categories.
# Column 'work_interfere' has 4 unique categories.
# Column 'no_employees' has 6 unique categories.
# Column 'remote_work' has 2 unique categories.
# Column 'tech_company' has 2 unique categories.
# Column 'benefits' has 3 unique categories.
# Column 'care_options' has 3 unique categories.
# Column 'wellness_program' has 3 unique categories.
# Column 'seek_help' has 3 unique categories.
# Column 'anonymity' has 3 unique categories.
# Column 'leave' has 5 unique categories.
# Column 'mental_health_consequence' has 3 unique categories.
# Column 'phys_health_consequence' has 3 unique categories.
# Column 'coworkers' has 3 unique categories.
# Column 'supervisor' has 3 unique categories.
# ...

# %%
df['Gender'].value_counts()
# Out:
# Male                                              615
# male                                              206
# Female                                            121
# M                                                 116
# female                                             62
# F                                                  38
# m                                                  34
# f                                                  15
# Make                                                4
# Male                                                3
# Woman                                               3
# Cis Male                                            2
# Man                                                 2
# Female (trans)                                      2
# Female                                              2
# Trans woman                                         1
# msle                                                1
# ...

# %%
df_df = df
df['Gender'].replace(['Male ', 'male', 'M', 'm', 'Male', 'Cis Male',
                     'Man', 'cis male', 'Mail', 'Male-ish', 'Male (CIS)',
                      'Cis Man', 'msle', 'Malr', 'Mal', 'maile', 'Make',], 'Male', inplace = True)

df['Gender'].replace(['Female ', 'female', 'F', 'f', 'Woman', 'Female',
                     'femail', 'Cis Female', 'cis-female/femme', 'Femake', 'Female (cis)',
                     'woman',], 'Female', inplace = True)

df["Gender"].replace(['Female (trans)', 'queer/she/they', 'non-binary',
                     'fluid', 'queer', 'Androgyne', 'Trans-female', 'male leaning androgynous',
                      'Agender', 'A little about you', 'Nah', 'All',
                      'ostensibly male, unsure what that really means',
                      'Genderqueer', 'Enby', 'p', 'Neuter', 'something kinda male?',
                      'Guy (-ish) ^_^', 'Trans woman',], 'Other', inplace = True)

df['Gender'].value_counts()
# Out:
# Male      991
# Female    247
# Other      21
# Name: Gender, dtype: int64

# %%
df['Gender'].isnull().value_counts()
# Out:
# False    1259
# Name: Gender, dtype: int64

# %%
df['Gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
# we may conclude that the number of males in the tech industry are much more as compared to the number of females as male is 4 times female

# %%
df['Country'].value_counts()
# Out:
# United States             751
# United Kingdom            185
# Canada                     72
# Germany                    45
# Ireland                    27
# Netherlands                27
# Australia                  21
# France                     13
# India                      10
# New Zealand                 8
# Poland                      7
# Switzerland                 7
# Sweden                      7
# Italy                       7
# South Africa                6
# Belgium                     6
# Brazil                      6
# Israel                      5
# Singapore                   4
# Bulgaria                    4
# Austria                     3
# Finland                     3
# Mexico                      3
# Russia                      3
# Denmark                     2
# Greece                      2
# Colombia                    2
# Croatia                     2
# Portugal                    2
# Moldova                     1
# Georgia                     1
# ...

# %%
df['state'].value_counts()
# Out:
# CA    138
# WA     70
# NY     57
# TN     45
# TX     44
# OH     30
# IL     29
# OR     29
# PA     29
# IN     27
# MI     22
# MN     21
# MA     20
# FL     15
# NC     14
# VA     14
# WI     12
# GA     12
# MO     12
# UT     11
# CO      9
# MD      8
# AL      8
# AZ      7
# OK      6
# NJ      6
# KY      5
# SC      5
# IA      4
# CT      4
# DC      4
# NV      3
# VT      3
# SD      3
# KS      3
# NH      3
# WY      2
# NM      2
# NE      2
# WV      1
# ID      1
# MS      1
# RI      1
# LA      1
# ME      1
# Name: state, dtype: int64

# %%
#It will be really misleading to conclude that a certain country faces more problem with the mental health of employees because around 60% of the people belong to The US.
#A quick look at the states suggest us that it is applicable for the one's only in The US, so we'll drop it as well.
#Hence both state and country column are pointless

# %%
df.drop(columns=['Country','state'],inplace=True)

# %%
df.head()
# Out:
#    Age  Gender self_employed family_history treatment work_interfere  \
# 0   37  Female           NaN             No       Yes          Often
# 1   44    Male           NaN             No        No         Rarely
# 2   32    Male           NaN             No        No         Rarely
# 3   31    Male           NaN            Yes       Yes          Often
# 4   31    Male           NaN             No        No          Never
#
#      no_employees remote_work tech_company    benefits  ...   anonymity  \
# 0            6-25          No          Yes         Yes  ...         Yes
# 1  More than 1000          No           No  Don't know  ...  Don't know
# 2            6-25          No          Yes          No  ...  Don't know
# 3          26-100          No          Yes          No  ...          No
# 4         100-500         Yes          Yes         Yes  ...  Don't know
#
#                 leave mental_health_consequence phys_health_consequence  \
# ...

# %%
df['Age'].value_counts()
# Out:
#  29             85
#  32             82
#  26             75
#  27             71
#  33             70
#  28             68
#  31             67
#  34             65
#  30             63
#  25             61
#  35             55
#  23             51
#  24             46
#  37             43
#  38             39
#  36             37
#  40             33
#  39             33
#  43             28
#  22             21
#  41             21
#  42             20
#  21             16
#  45             12
#  46             12
#  44             11
#  19              9
#  18              7
#  48              6
#  50              6
#  20              6
#  51              5
#  49              4
#  56              4
#  57              3
#  54              3
#  55              3
#  47              2
#  60              2
#  99999999999     1
#  5               1
# -1               1
#  11              1
#  8               1
#  61              1
#  53              1
# -29              1
# ...

# %%
#we are removing some irrelevant ages

# %%
df.drop(df[df['Age'] < 0].index, inplace = True)
df.drop(df[df['Age'] > 100].index, inplace = True)
df['Age'].unique()
# Out:
# array([37, 44, 32, 31, 33, 35, 39, 42, 23, 29, 36, 27, 46, 41, 34, 30, 40,
#        38, 50, 24, 18, 28, 26, 22, 19, 25, 45, 21, 43, 56, 60, 54, 55, 48,
#        20, 57, 58, 47, 62, 51, 65, 49,  5, 53, 61,  8, 11, 72])

# %%
df.isnull().sum()
# Out:
# Age                            0
# Gender                         0
# self_employed                 18
# family_history                 0
# treatment                      0
# work_interfere               263
# no_employees                   0
# remote_work                    0
# tech_company                   0
# benefits                       0
# care_options                   0
# wellness_program               0
# seek_help                      0
# anonymity                      0
# leave                          0
# mental_health_consequence      0
# phys_health_consequence        0
# coworkers                      0
# supervisor                     0
# mental_health_interview        0
# phys_health_interview          0
# mental_vs_physical             0
# obs_consequence                0
# dtype: int64

# %%
df['self_employed'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['self_employed'] = df['self_employed'].fillna('No')

# %%
df['self_employed'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['work_interfere'].value_counts()
# Out:
# Sometimes    464
# Never        213
# Rarely       173
# Often        141
# Name: work_interfere, dtype: int64

# %%
df_df1 = df

# %%
df['work_interfere'] = df['work_interfere'].fillna('Don\'t know' )

# %%
df['work_interfere'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

num_columns_per_row = 3

plt.figure(figsize=(26, 12))

for i, column in enumerate(df.columns):
    if column == 'treatment':
        continue

    plt.subplot((len(df.columns) - 1) // num_columns_per_row + 1, num_columns_per_row, i + 1)

    sns.countplot(x=column, hue='treatment', data=df)

    plt.title(column)

    plt.xticks(rotation=45)

    plt.legend(loc='upper right')

plt.tight_layout()

plt.show()
# Out:
# <ipython-input-42-a939da51ede6>:22: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
df.isnull().sum()
# Out:
# Age                          0
# Gender                       0
# self_employed                0
# family_history               0
# treatment                    0
# work_interfere               0
# no_employees                 0
# remote_work                  0
# tech_company                 0
# benefits                     0
# care_options                 0
# wellness_program             0
# seek_help                    0
# anonymity                    0
# leave                        0
# mental_health_consequence    0
# phys_health_consequence      0
# coworkers                    0
# supervisor                   0
# mental_health_interview      0
# phys_health_interview        0
# mental_vs_physical           0
# obs_consequence              0
# dtype: int64

# %%
df.shape
# Out:
# (1254, 23)

# %%
for column in df.columns:
  if df[column].dtype =='object':
    num_unique_values = df[column].nunique()
    print(f"Column '{column}' has {num_unique_values} unique categories.")
# Out:
# Column 'Gender' has 3 unique categories.
# Column 'self_employed' has 2 unique categories.
# Column 'family_history' has 2 unique categories.
# Column 'treatment' has 2 unique categories.
# Column 'work_interfere' has 5 unique categories.
# Column 'no_employees' has 6 unique categories.
# Column 'remote_work' has 2 unique categories.
# Column 'tech_company' has 2 unique categories.
# Column 'benefits' has 3 unique categories.
# Column 'care_options' has 3 unique categories.
# Column 'wellness_program' has 3 unique categories.
# Column 'seek_help' has 3 unique categories.
# Column 'anonymity' has 3 unique categories.
# Column 'leave' has 5 unique categories.
# Column 'mental_health_consequence' has 3 unique categories.
# Column 'phys_health_consequence' has 3 unique categories.
# Column 'coworkers' has 3 unique categories.
# Column 'supervisor' has 3 unique categories.
# Column 'mental_health_interview' has 3 unique categories.
# ...

# %%
df['Age'].unique()
# Out:
# array([37, 44, 32, 31, 33, 35, 39, 42, 23, 29, 36, 27, 46, 41, 34, 30, 40,
#        38, 50, 24, 18, 28, 26, 22, 19, 25, 45, 21, 43, 56, 60, 54, 55, 48,
#        20, 57, 58, 47, 62, 51, 65, 49,  5, 53, 61,  8, 11, 72])

# %%
new_df = df

# %%
from sklearn.preprocessing import LabelEncoder

def label_encode_dataframe(df, exclude_column):
  encoded_df = df.copy()
  label_encoder = LabelEncoder()
  for column in encoded_df.columns:
    if column != exclude_column and encoded_df[column].dtype == 'object':
      encoded_df[column] = label_encoder.fit_transform(encoded_df[column])

  return encoded_df
exclude_column = 'Age'
encoded_df = label_encode_dataframe(new_df,exclude_column)
encoded_df.head()
# Out:
#    Age  Gender  self_employed  family_history  treatment  work_interfere  \
# 0   37       0              0               0          1               2
# 1   44       1              0               0          0               3
# 2   32       1              0               0          0               3
# 3   31       1              0               1          1               2
# 4   31       1              0               0          0               1
#
#    no_employees  remote_work  tech_company  benefits  ...  anonymity  leave  \
# 0             4            0             1         2  ...          2      2
# 1             5            0             0         0  ...          0      0
# 2             4            0             1         1  ...          0      1
# 3             2            0             1         1  ...          1      1
# 4             1            1             1         2  ...          0      0
#
# ...

# %%
correlation_matrix = encoded_df.corr()

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
def value_count(df):
  for i in df.columns:
    if(i=='Age'):
      pass
    else:
      print(df[i].value_counts())

value_count(new_df)
# Out:
# Male      988
# Female    247
# Other      19
# Name: Gender, dtype: int64
# No     1110
# Yes     144
# Name: self_employed, dtype: int64
# No     764
# Yes    490
# Name: family_history, dtype: int64
# Yes    633
# No     621
# Name: treatment, dtype: int64
# Sometimes     464
# Don't know    263
# Never         213
# Rarely        173
# Often         141
# Name: work_interfere, dtype: int64
# 6-25              289
# 26-100            288
# More than 1000    281
# 100-500           176
# 1-5               160
# 500-1000           60
# Name: no_employees, dtype: int64
# No     881
# Yes    373
# Name: remote_work, dtype: int64
# Yes    1028
# No      226
# Name: tech_company, dtype: int64
# Yes           474
# Don't know    408
# No            372
# Name: benefits, dtype: int64
# No          499
# Yes         441
# Not sure    314
# Name: care_options, dtype: int64
# No            839
# Yes           228
# Don't know    187
# Name: wellness_program, dtype: int64
# No            643
# ...

# %%
def value_count(df):
  for i in df.columns:
    if(i=='Age'):
      pass
    else:
      print(df[i].value_counts())

value_count(encoded_df)
# Out:
# 1    988
# 0    247
# 2     19
# Name: Gender, dtype: int64
# 0    1110
# 1     144
# Name: self_employed, dtype: int64
# 0    764
# 1    490
# Name: family_history, dtype: int64
# 1    633
# 0    621
# Name: treatment, dtype: int64
# 4    464
# 0    263
# 1    213
# 3    173
# 2    141
# Name: work_interfere, dtype: int64
# 4    289
# 2    288
# 5    281
# 1    176
# 0    160
# 3     60
# Name: no_employees, dtype: int64
# 0    881
# 1    373
# Name: remote_work, dtype: int64
# 1    1028
# 0     226
# Name: tech_company, dtype: int64
# 2    474
# 0    408
# 1    372
# Name: benefits, dtype: int64
# 0    499
# 2    441
# 1    314
# Name: care_options, dtype: int64
# 1    839
# 2    228
# 0    187
# Name: wellness_program, dtype: int64
# 1    643
# 0    363
# 2    248
# Name: seek_help, dtype: int64
# 0    816
# 2    374
# 1     64
# Name: anonymity, dtype: int64
# 0    561
# 2    266
# 4    205
# 1    125
# 3     97
# Name: leave, dtype: int64
# 1    489
# 0    476
# 2    289
# ...

# %%
from sklearn.model_selection import train_test_split
x = encoded_df.drop(columns=['treatment']);
y = encoded_df['treatment']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Decision Tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
dt_model = DecisionTreeClassifier()
dt_model.fit(X_train, y_train)
dt_pred = dt_model.predict(X_test)
dt_accuracy = accuracy_score(y_test, dt_pred)
print("Decision Tree Accuracy:", dt_accuracy)
dt_train_predictions = dt_model.predict(X_train)
dt_train_accuracy = accuracy_score(y_train, dt_train_predictions)
print("Accuracy on training data:", dt_train_accuracy)
# Out:
# Decision Tree Accuracy: 0.7131474103585658
# Accuracy on training data: 1.0

# %%
from sklearn.model_selection import GridSearchCV
import numpy as np
dt_classifier = DecisionTreeClassifier(random_state=42)
param_grid = {
    'max_depth': np.arange(1, 3),  # Maximum depth of the tree
    'min_samples_split': np.arange(2, 5),  # Minimum number of samples required to split an internal node
    'min_samples_leaf': np.arange(1, 3)  # Minimum number of samples required to be at a leaf node
}
# Perform Grid Search Cross-Validation
grid_search = GridSearchCV(estimator=dt_classifier, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)

# Extract results
results = grid_search.cv_results_
params = results['params']
mean_test_score = results['mean_test_score']

# Convert params to a list of strings
param_strings = [str(param) for param in params]

# Plot grid search results
plt.figure(figsize=(10, 6))
plt.scatter(param_strings, mean_test_score, c='b', marker='o')
plt.xlabel('Hyperparameters')
plt.ylabel('Mean Test Score')
plt.title('Grid Search Cross-Validation Results')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
dt_classifier = DecisionTreeClassifier(random_state=42)

param_grid = {
    'max_depth': [2],  # Maximum depth of the tree
    'min_samples_split': np.arange(5,7),  # Minimum number of samples required to split an internal node
    'min_samples_leaf': np.arange( 4,6)  # Minimum number of samples required to be at a leaf node
}
# Perform Grid Search Cross-Validation
grid_search = GridSearchCV(estimator=dt_classifier, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)

# Extract results
results = grid_search.cv_results_
params = results['params']
mean_test_score = results['mean_test_score']

# Convert params to a list of strings
param_strings = [str(param) for param in params]

# Plot grid search results
plt.figure(figsize=(10, 6))
plt.scatter(param_strings, mean_test_score, c='b', marker='o')
plt.xlabel('Hyperparameters')
plt.ylabel('Mean Test Score')
plt.title('Grid Search Cross-Validation Results')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
dt_classifier = DecisionTreeClassifier(random_state=42)

param_grid = {
    'max_depth': [2],  # Maximum depth of the tree
    'min_samples_split': np.arange(8,10),  # Minimum number of samples required to split an internal node
    'min_samples_leaf': np.arange( 7,9)  # Minimum number of samples required to be at a leaf node
}
# Perform Grid Search Cross-Validation
grid_search = GridSearchCV(estimator=dt_classifier, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)

# Extract results
results = grid_search.cv_results_
params = results['params']
mean_test_score = results['mean_test_score']

# Convert params to a list of strings
param_strings = [str(param) for param in params]

# Plot grid search results
plt.figure(figsize=(10, 6))
plt.scatter(param_strings, mean_test_score, c='b', marker='o')
plt.xlabel('Hyperparameters')
plt.ylabel('Mean Test Score')
plt.title('Grid Search Cross-Validation Results')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
dt_model = DecisionTreeClassifier(max_depth=2,min_samples_split=4,min_samples_leaf=5)
dt_model.fit(X_train, y_train)
dt_pred = dt_model.predict(X_test)
dt_accuracy = accuracy_score(y_test, dt_pred)
print("Decision Tree Accuracy:", dt_accuracy)
dt_train_predictions = dt_model.predict(X_train)
dt_train_accuracy = accuracy_score(y_train, dt_train_predictions)
print("Accuracy on training data:", dt_train_accuracy)
# Out:
# Decision Tree Accuracy: 0.8247011952191236
# Accuracy on training data: 0.8315054835493519

# %%
# K-Nearest Neighbors (KNN)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
knn_model = KNeighborsClassifier()
knn_model.fit(X_train, y_train)
knn_pred = knn_model.predict(X_test)
knn_accuracy = accuracy_score(y_test, knn_pred)
print("KNN Accuracy on test data :", knn_accuracy)
knn_train_predictions = knn_model.predict(X_train)
knn_train_accuracy = accuracy_score(y_train, knn_train_predictions)
print("Accuracy on training data:", knn_train_accuracy)
# Out:
# KNN Accuracy on test data : 0.7410358565737052
# Accuracy on training data: 0.8534396809571286

# %%
# Support Vector Machine (SVM)
from sklearn.svm import SVC
svm_model = SVC()
svm_model.fit(X_train, y_train)
svm_pred = svm_model.predict(X_test)
svm_accuracy = accuracy_score(y_test, svm_pred)
print("SVM Accuracy:", svm_accuracy)
svm_train_predictions = svm_model.predict(X_train)
svm_train_accuracy = accuracy_score(y_train, knn_train_predictions)
print("Accuracy on training data:", knn_train_accuracy)
# Out:
# SVM Accuracy: 0.8087649402390438
# Accuracy on training data: 0.8534396809571286

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)
rf_accuracy = accuracy_score(y_test, rf_pred)
print("Random Forest Accuracy:", rf_accuracy)
# Out:
# Random Forest Accuracy: 0.8127490039840638

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
lr_model = LogisticRegression()
lr_model.fit(X_train, y_train)
lr_pred = lr_model.predict(X_test)
lr_accuracy = accuracy_score(y_test, lr_pred)
print("Logistic Regression Accuracy:", lr_accuracy)
# Out:
# Logistic Regression Accuracy: 0.796812749003984

# %%
from sklearn.tree import DecisionTreeClassifier
dt_model = DecisionTreeClassifier(max_depth=7,min_samples_split=18,min_samples_leaf=10)
dt_model.fit(X_train, y_train)
dt_pred = dt_model.predict(X_test)
dt_accuracy = accuracy_score(y_test, dt_pred)
print("Decision Tree Accuracy:", dt_accuracy)
dt_train_predictions = dt_model.predict(X_train)
dt_train_accuracy = accuracy_score(y_train, dt_train_predictions)
print("Accuracy on training data:", dt_train_accuracy)
# Out:
# Decision Tree Accuracy: 0.7928286852589641
# Accuracy on training data: 0.8554336989032901

# %%
rf_classifier = RandomForestClassifier(random_state=42)

param_grid = {
    'n_estimators': [50, 100, 150],  # Number of trees in the forest
    'max_depth': [4, 6, 8],  # Maximum depth of the trees
    'min_samples_split': [2, 5, 10],  # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 4]  # Minimum number of samples required to be at a leaf node
}

# Perform Grid Search Cross-Validation
grid_search = GridSearchCV(estimator=rf_classifier, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)

# Extract results
results = grid_search.cv_results_
params = results['params']
mean_test_score = results['mean_test_score']

# Get the best parameters
best_params = grid_search.best_params_

# Convert params to a list of strings
param_strings = [str(param) for param in params]

# Plot grid search results
plt.figure(figsize=(10, 6))
plt.scatter(param_strings, mean_test_score, c='b', marker='o')
plt.xlabel('Hyperparameters')
plt.ylabel('Mean Test Score')
plt.title('Grid Search Cross-Validation Results')
plt.xticks(rotation=90)

# Show the best hyperparameters
plt.text(0.5, -0.1, f'Best Hyperparameters: {best_params}', horizontalalignment='center', verticalalignment='center', transform=plt.gca().transAxes, fontsize=12)

plt.grid(True)
plt.show()

# %%
#max_depth : 6 , min_samples_leaf : 1 , min_samples-splits : 2 , n-estimators : 150

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(max_depth=6,min_samples_leaf=1,min_samples_split=2,n_estimators=150)
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)
rf_accuracy = accuracy_score(y_test, rf_pred)
print("Random Forest Accuracy:", rf_accuracy)
rf_train_predictions = rf_model.predict(X_train)
rf_train_accuracy = accuracy_score(y_train, rf_train_predictions)
print("Accuracy on training data:", rf_train_accuracy)
# Out:
# Random Forest Accuracy: 0.8047808764940239
# Accuracy on training data: 0.8753738783649053

# %%
#ANN
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

ann_model = Sequential()
ann_model.add(Dense(units=32, activation='relu', input_dim=X_train.shape[1]))
ann_model.add(Dense(units=16, activation='relu'))
ann_model.add(Dense(units=1, activation='sigmoid'))

ann_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])


ann_model.fit(X_train, y_train, epochs=15, batch_size=32, verbose=1)

ann_accuracy = ann_model.evaluate(X_test, y_test)[1]
print("ANN Accuracy on test data:", ann_accuracy)

ann_train_accuracy = ann_model.evaluate(X_train, y_train)[1]
print("ANN Accuracy on training data:", ann_train_accuracy)
# Out:
# Epoch 1/15
# 32/32 [==============================] - 1s 2ms/step - loss: 1.3859 - accuracy: 0.4865
# Epoch 2/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6872 - accuracy: 0.5813
# Epoch 3/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6212 - accuracy: 0.6830
# Epoch 4/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5884 - accuracy: 0.7099
# Epoch 5/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5538 - accuracy: 0.7268
# Epoch 6/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5275 - accuracy: 0.7537
# Epoch 7/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5081 - accuracy: 0.7687
# Epoch 8/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4889 - accuracy: 0.7747
# Epoch 9/15
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4745 - accuracy: 0.7936
# Epoch 10/15
# ...

# %%
#xgboost
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

xgb_model = XGBClassifier()
xgb_model.fit(X_train, y_train)

xgb_pred = xgb_model.predict(X_test)

xgb_accuracy = accuracy_score(y_test, xgb_pred)
print("XGBoost Classifier Accuracy:", xgb_accuracy)

xgb_train_pred = xgb_model.predict(X_train)

xgb_train_accuracy = accuracy_score(y_train, xgb_train_pred)
print("Accuracy on training data:", xgb_train_accuracy)
# Out:
# XGBoost Classifier Accuracy: 0.7649402390438247
# Accuracy on training data: 1.0

# %%
#GradientBoosting
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# Initialize the GradientBoostingClassifier
gb_model = GradientBoostingClassifier()

# Train the model
gb_model.fit(X_train, y_train)

# Predict on the test data
gb_pred = gb_model.predict(X_test)

# Calculate accuracy on the test data
gb_accuracy = accuracy_score(y_test, gb_pred)
print("GradientBoostingClassifier Accuracy:", gb_accuracy)

# Predict on the training data (to check overfitting)
gb_train_pred = gb_model.predict(X_train)

# Calculate accuracy on the training data
gb_train_accuracy = accuracy_score(y_train, gb_train_pred)
print("Accuracy on training data:", gb_train_accuracy)
# Out:
# GradientBoostingClassifier Accuracy: 0.8127490039840638
# Accuracy on training data: 0.8743768693918246

# %%
#AdaBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score

# Initialize the AdaBoostClassifier
ada_model = AdaBoostClassifier()

# Train the model
ada_model.fit(X_train, y_train)

# Predict on the test data
ada_pred = ada_model.predict(X_test)

# Calculate accuracy on the test data
ada_accuracy = accuracy_score(y_test, ada_pred)
print("AdaBoostClassifier Accuracy:", ada_accuracy)

# Predict on the training data (to check overfitting)
ada_train_pred = ada_model.predict(X_train)

# Calculate accuracy on the training data
ada_train_accuracy = accuracy_score(y_train, ada_train_pred)
print("Accuracy on training data:", ada_train_accuracy)
# Out:
# AdaBoostClassifier Accuracy: 0.8047808764940239
# Accuracy on training data: 0.8354935194416749
